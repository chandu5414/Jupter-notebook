# %% [markdown]
# # My Jyputer Notebook on watson studio

# %% [markdown]
# __NAGA CHANDRA SEKHAR CHOUDARY__

# %% [markdown]
# STUDENT,DATA SCIENTIST

# %% [markdown]
# *I am interested in data science Because i like to anlyse the data and find the solutions of many problems using the data.*

# %% [markdown]
# ### The following code displays todays data and time

# %%
import datetime 
message = "Today's Date and Time is " 
print (message , datetime.datetime.now() )
# Out:
# Today's Date and Time is  2022-10-22 14:28:00.912719

# %% [markdown]
# - *one*
# - *two*
# - *three*
# - *one*
# - *two*
# - *three*
